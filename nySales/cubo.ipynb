# %%
import pandas as pd

# %%
df=pd.read_csv("nyc-rolling-sales.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
df.transpose()
# Out:
#                                                                       0      \
# Unnamed: 0                                                                4
# BOROUGH                                                                   1
# NEIGHBORHOOD                                                  ALPHABET CITY
# BUILDING CLASS CATEGORY         07 RENTALS - WALKUP APARTMENTS
# TAX CLASS AT PRESENT                                                     2A
# BLOCK                                                                   392
# LOT                                                                       6
# EASE-MENT
# BUILDING CLASS AT PRESENT                                                C2
# ADDRESS                                                        153 AVENUE B
# APARTMENT NUMBER
# ZIP CODE                                                              10009
# RESIDENTIAL UNITS                                                         5
# ...

# %%
geo=df[["BOROUGH","NEIGHBORHOOD","BLOCK","LOT","ADDRESS","ZIP CODE"]]
present=df[['BUILDING CLASS CATEGORY','BUILDING CLASS AT PRESENT','TAX CLASS AT PRESENT']]
sale=df[['BUILDING CLASS CATEGORY','TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE']]
center=df[['RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS','LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT','SALE PRICE', 'SALE DATE']]
center.head()
# Out:
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS LAND SQUARE FEET  \
# 0                  5                 0            5             1633
# 1                 28                 3           31             4616
# 2                 16                 1           17             2212
# 3                 10                 0           10             2272
# 4                  6                 0            6             2369
#
#   GROSS SQUARE FEET  YEAR BUILT SALE PRICE            SALE DATE
# 0              6440        1900    6625000  2017-07-19 00:00:00
# 1             18690        1900        -    2016-12-14 00:00:00
# 2              7803        1900        -    2016-12-09 00:00:00
# 3              6794        1913    3936272  2016-09-23 00:00:00
# 4              4615        1900    8000000  2016-11-17 00:00:00

# %%
df.groupby(["BOROUGH","NEIGHBORHOOD","BLOCK","LOT","ADDRESS","ZIP CODE"]).count()
# Out:
#                                                                    Unnamed: 0  \
# BOROUGH NEIGHBORHOOD  BLOCK LOT  ADDRESS                 ZIP CODE
# 1       ALPHABET CITY 372   1003 296 EAST 2ND STREET     10009              1
#                             1004 296 EAST 2ND   STREET   10009              1
#                       373   40   327 EAST 3 STREET, 1C   10009              2
#                                  327 EAST 3 STREET, 2E   10009              1
#                                  327 EAST 3 STREET, 3A   10009              1
#                                  327 EAST 3RD STREET, 5A 10009              1
#                             46   317 EAST 3RD STREET, 12 10009              1
#                             49   311 EAST 3RD STREET, 17 10009              1
#                                  311 EAST 3RD, 22        10009              1
#                             1003 324 EAST 4TH STREET     10009              1
# ...

# %% [markdown]
# ##
